# %%
import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB

from sklearn.metrics import recall_score, precision_score, f1_score

# %%
DATA_JSON_FILE = 'SpamData/01_Processing/email-text-data.json'

# %%
data = pd.read_json(DATA_JSON_FILE)

# %%
data.tail()
# Out:
#                                                 MESSAGE  CATEGORY  \
# 5791  On Tue, 23 Jul 2002, Jim Whitehead wrote:\n\n\...         0
# 5792  wintermute wrote:\n\n>>Anyone know where in Ir...         0
# 5793  hey,\n\n\n\nAFAIK it isn't hard at all to crea...         0
# 5794  Evidently, I have permission to pass this alon...         0
# 5795  On Mon, 19 Aug 2002 16:44:30 +0200, Matthias S...         0
#
#                                    FILE_NAME
# 5791  00846.a603afcbab0796cbe45d3be854562598
# 5792  00424.e39b1db8cf5575572abb4482fd3fced3
# 5793  00374.957837ba252b473057711e3c4dbd1e26
# 5794  01101.ff91c2c8fb18ed6e300ed2ac699f8ae4
# 5795  01266.94f7e1cce0ec1935ca75d232e4dc684c

# %%
data.shape
# Out:
# (5796, 3)

# %%
vectorizer = CountVectorizer(stop_words='english')

# %%
all_features = vectorizer.fit_transform(data.MESSAGE)

# %%
all_features.shape
# Out:
# (5796, 102694)

# %%
vectorizer.vocabulary_
# Out:
# {'html': 48472,
#  'head': 47011,
#  'meta': 61701,
#  'http': 48497,
#  'equiv': 38991,
#  '3d': 6385,
#  'content': 30249,
#  'language': 57500,
#  'en': 38432,
#  'generator': 44258,
#  'microsoft': 62003,
#  'frontpage': 43005,
#  'progid': 73406,
#  'editor': 37557,
#  'document': 34867,
#  'type': 89371,
#  'text': 86991,
#  'charset': 27796,
#  '3dwindows': 7297,
#  '1252': 2025,
#  'title': 87725,
#  'norton': 65833,
#  'ad': 16973,
#  'body': 24390,
#  'table': 86120,
#  'border': 24581,
#  'width': 95488,
#  '489': 8330,
#  'height': 47157,
#  '54': 9185,
#  'bgcolor': 23297,
#  'ffffff': 41323,
#  'tr': 88442,
#  'td': 86548,
#  '100': 1496,
#  '48': 8295,
#  'align': 18634,
#  'center': 27405,
#  'font': 42257,
#  'face': 40498,
#  'impact': 51290,
#  'color': 29367,
#  'cc0000': 27108,
#  'size': 82347,
#  'control': 30335,
#  'computer': 29755,
#  'line': 58568,
#  'software': 83094,
#  'cellspacing': 27383,
#  'cellpadding': 27375,
#  'bgco': 23295,
#  'lor': 59273,
#  '990033': 13977,
#  'bordercolor': 24584,
#  'style': 84723,
#  'collapse': 29305,
#  'collaps': 29304,
#  'bordercolordark': 24585,
#  '000000': 4,
#  '567': 9317,
#  'bordercolorlight': 24586,
#  'ffff99': 41316,
#  '467': 8224,
#  '555': 9260,
#  'borderco': 24582,
#  'lordark': 59276,
#  '86': 12651,
#  '80': 12020,
#  'ff0000': 41235,
#  'tahoma': 86190,
#  'systemworks': 85743,
#  '2002': 3508,
#  'suite': 85010,
#  'times': 87641,
#  'ew': 39565,
#  'roman': 78896,
#  'br': 24813,
#  'professional': 73364,
#  'edition': 37555,
#  '62': 10140,
#  '56': 9286,
#  'includes': 51529,
#  'fff': 41299,
#  'f99': 40445,
#  'yes': 98554,
#  'feature': 41058,
#  'packed': 69127,
#  'utilities': 91474,
#  'tah': 86183,
#  'oma': 67543,
#  'special': 83501,
#  'ffff': 41309,
#  '99': 13970,
#  'low': 59355,
#  'price': 73136,
#  '29': 4793,
#  '135': 2165,
#  '800000': 12024,
#  '129': 2068,
#  'bordercolo': 24583,
#  'nbsp': 64561,
#  'protect': 73612,
#  'unwanted': 91011,
#  'hazardous': 46863,
#  'vir': 92850,
#  'uses': 91371,
#  'help': 47200,
#  'secure': 81012,
#  'private': 73228,
#  'amp': 19047,
#  'valuable': 92057,
#  'information': 51875,
#  'allow': 18722,
#  'transfer': 88556,
#  'files': 41540,
#  'send': 81178,
#  'mails': 60404,
#  'safely': 80079,
#  'backup': 22191,
#  'data': 32319,
#  'quick': 75547,
#  'easily': 37275,
#  'improve': 51396,
#  'pc': 69756,
#  'performance': 70486,
#  'superior': 85124,
#  'integral': 52274,
#  'diagnostics': 33895,
#  'll': 58888,
#  'repair': 77570,
#  'shop': 81840,
#  '000080': 37,
#  'great': 45565,
#  '300': 5594,
#  'combined': 29424,
#  'retail': 77958,
#  'value': 92060,
#  '00': 0,
#  '0000': 2,
#  'lt': 59561,
#  'free': 42773,
#  'shipping': 81777,
#  'gt': 45820,
#  'limited': 58543,
#  'time': 87625,
#  'buy': 25611,
#  'products': 73349,
#  'arial': 20116,
#  'ff': 41231,
#  'don': 34992,
#  'fall': 40613,
#  'prey': 73130,
#  'destructive': 33432,
#  'viruses': 92887,
#  'hackers': 46445,
#  '44': 8096,
#  '38': 6143,
#  'ce': 27294,
#  'nter': 66145,
#  'href': 48390,
#  'www': 96531,
#  'anythinggoeshere': 19546,
#  'com': 29405,
#  'ff0': 41232,
#  '000': 1,
#  'family': 40651,
#  'verdana': 92415,
#  '14pt': 2333,
#  'weight': 95115,
#  'bold': 24438,
#  'click': 28719,
#  'order': 68036,
#  'toll': 88097,
#  '800': 12021,
#  '861': 12656,
#  '1481': 2308,
#  'tahom': 86189,
#  'email': 38216,
#  'address': 17095,
#  'obtained': 66877,
#  'opt': 67895,
#  'list': 58680,
#  'uefas': 89880,
#  'united': 90759,
#  'federation': 41084,
#  'spam': 83390,
#  'approved': 19837,
#  'purchase': 74123,
#  'code': 29201,
#  '8594030': 12630,
#  'wish': 95691,
#  'unsubscribed': 90959,
#  'lease': 57906,
#  'ffffcc': 41319,
#  'remove': 77467,
#  'asp': 20429,
#  'previously': 73127,
#  'receivi': 76793,
#  'ng': 65158,
#  'message': 61680,
#  'abuse': 16529,
#  'condone': 29855,
#  'shape': 81635,
#  'thank': 87162,
#  'kindly': 56143,
#  'cooperation': 30419,
#  'note': 65874,
#  'unsolicited': 90939,
#  'receiving': 76794,
#  'opted': 67899,
#  'receive': 76783,
#  'certain': 27468,
#  'offers': 67168,
#  'partnering': 69525,
#  'sites': 82305,
#  'changed': 27720,
#  'mind': 62166,
#  'want': 94159,
#  'stop': 84428,
#  'unsubscribe': 90955,
#  'link': 58601,
#  'removed': 77482,
#  'dear': 32719,
#  'subscriber': 84839,
#  'moment': 62812,
#  'feel': 41102,
#  'messages': 61684,
#  'error': 39109,
#  'going': 45187,
#  'clicking': 28730,
#  'offer': 67158,
#  '08': 770,
#  '26': 4538,
#  '2202': 4005,
#  'pm': 72142,
#  'sexual': 81458,
#  'fitness': 41733,
#  'penis': 70414,
#  'enlargement': 38638,
#  'video': 92721,
#  'week': 95087,
#  'choking': 28063,
#  'chinese': 28004,
#  'chicken': 27960,
#  'caught': 27005,
#  'tape': 86325,
#  'asian': 20388,
#  'guy': 45990,
#  'dressing': 36183,
#  'room': 78933,
#  'hell': 47188,
#  'doing': 34927,
#  'actually': 16941,
#  'chocking': 28050,
#  'check': 27852,
#  '515352': 9043,
#  'page': 69156,
#  'subject': 84789,
#  'male': 60546,
#  'strengthening': 84567,
#  'total': 88259,
#  'just': 55049,
#  'wanted': 94160,
#  'remind': 77433,
#  'month': 62908,
#  'program': 73408,
#  'following': 42233,
#  'increase': 51582,
#  'permanent': 70545,
#  'length': 58027,
#  'pre': 72861,
#  'mature': 60985,
#  'ejaculation': 37947,
#  'erectile': 39032,
#  'dysfunction': 36783,
#  'strength': 84564,
#  'make': 60515,
#  'meaty': 61389,
#  'enlarge': 38637,
#  'glans': 44877,
#  'staying': 84221,
#  'power': 72689,
#  'distance': 34462,
#  'volume': 93217,
#  'plus': 72122,
#  'new': 64988,
#  'start': 84135,
#  'extreme': 40089,
#  'jump': 55000,
#  'using': 91383,
#  'frills': 42951,
#  'bare': 22422,
#  'bones': 24484,
#  'cram': 30893,
#  'course': 30683,
#  'set': 81382,
#  'gaining': 43819,
#  'performing': 70491,
#  'better': 23177,
#  'really': 76664,
#  'short': 81854,
#  'finish': 41644,
#  'explore': 39962,
#  'totally': 88271,
#  'option': 67936,
#  'library': 58376,
#  'search': 80915,
#  'instructional': 52223,
#  'original': 68112,
#  'amateur': 18895,
#  'entertainment': 38719,
#  'videos': 92727,
#  'inside': 52124,
#  '40': 7824,
#  'different': 33995,
#  'techniques': 86646,
#  'explained': 39940,
#  'step': 84282,
#  'best': 23129,
#  'money': 62840,
#  'pound': 72670,
#  'lowest': 59365,
#  'net': 64868,
#  'today': 88039,
#  'info': 51836,
#  'faq': 40686,
#  'testimonials': 86959,
#  'ordering': 68042,
#  'business': 25553,
#  'opps': 67885,
#  'advertising': 17349,
#  'bigthangz': 23574,
#  'boost': 24543,
#  'sales': 80134,
#  'seen': 81064,
#  'millions': 62118,
#  'widely': 95472,
#  'circulated': 28338,
#  'magazines': 60258,
#  'newspapers': 65074,
#  'nationwide': 64470,
#  'join': 54666,
#  'permission': 70552,
#  'based': 22490,
#  'ring': 78465,
#  'blow': 24091,
#  'roof': 78925,
#  'ask': 20404,
#  'numbers': 66252,
#  '10': 1495,
#  'coming': 29461,
#  'soon': 83225,
#  'mailings': 60385,
#  'getresponse': 44423,
#  'cgi': 27613,
#  'specialweboffers': 83520,
#  'zzzz_xyspamassassin': 101426,
#  'taint': 86206,
#  'org': 68066,
#  '_nextpart_000_00d1_61b37d4a': 15020,
#  'a0476b56': 15359,
#  'iso': 53094,
#  '8859': 12828,
#  '725': 11196,
#  'tbody': 86462,
#  '8pt': 13380,
#  'valign': 92046,
#  '470': 8248,
#  'rowspan': 79053,
#  '111': 1813,
#  '723': 11189,
#  'colspan': 29390,
#  'ff6600': 41253,
#  'introduction': 52524,
#  'sell': 81130,
#  'cds': 27273,
#  'known': 56472,
#  'warez': 94209,
#  'copies': 30440,
#  'example': 39660,
#  'windows': 95603,
#  'xp': 97537,
#  'pro': 73257,
#  '299': 4826,
#  'serial': 81293,
#  'cd': 27206,
#  'box': 24698,
#  'manual': 60690,
#  'number': 66246,
#  'works': 96058,
#  'exactly': 39642,
#  '19': 2800,
#  'saving': 80382,
#  '280': 4711,
#  'difference': 33992,
#  'colorful': 29375,
#  'useful': 91324,
#  'features': 41061,
#  '400': 7825,
#  'applications': 19780,
#  '1500': 2341,
#  'games': 43873,
#  'reply': 77619,
#  'requests': 77711,
#  'hours': 48261,
#  'newest': 65013,
#  'releases': 77334,
#  'web': 94964,
#  'choice': 28053,
#  'ship': 81770,
#  'orders': 68044,
#  'worldwide': 96085,
#  'credit': 30975,
#  'card': 26760,
#  'processing': 73304,
#  'authorized': 20930,
#  'retailer': 77959,
#  'passed': 69544,
#  'server': 81344,
#  'encrypted': 38487,
#  '128bit': 2061,
#  'need': 64740,
#  'worry': 96100,
#  'steal': 84244,
#  'details': 33442,
#  '200': 3487,
#  '159': 2436,
#  '16': 2462,
#  'popular': 72469,
#  '61': 10092,
#  '12': 1955,
#  '143': 2261,
#  'img': 51212,
#  'src': 83872,
#  'images': 51166,
#  'amazon': 18910,
#  'b000063emg': 21591,
#  '01': 309,
#  'tzzzzzzz': 89435,
#  'jpg': 54782,
#  '50': 8926,
#  'nosend': 65846,
#  'adobe': 17235,
#  'photoshop': 71362,
#  'finall': 41590,
#  '14': 2224,
#  'hr': 48373,
#  '51': 9018,
#  'relib': 77359,
#  'news': 65033,
#  'pic': 71485,
#  'windows_xp_white': 95604,
#  'gif': 44644,
#  'ms': 63335,
#  '53': 9118,
#  '52': 9072,
#  'b00005afi1': 21589,
#  'office': 67173,
#  '3cd': 6348,
#  '559': 9272,
#  '226': 4095,
#  '485': 8315,
#  '464': 8218,
#  '18': 2693,
#  'gratitude': 45536,
#  'customers': 31479,
#  '500': 8927,
#  'john': 54644,
#  'stewart': 84322,
#  'thanks': 87167,
#  'guys': 45999,
#  'got': 45295,
#  'work': 96033,
#  'promised': 73479,
#  'happy': 46653,
#  'customer': 31476,
#  'ready': 76638,
#  '77': 11411,
#  'mike': 62072,
#  'sandell': 80225,
#  'ordered': 68039,
#  'arrived': 20207,
#  'little': 58765,
#  'suspicious': 85295,
#  'stuff': 84680,
#  'wrong': 96282,
#  'services': 81361,
#  'let': 58083,
#  'site': 82284,
#  '70': 11063,
#  'chris': 28094,
#  'anderson': 19193,
#  'marks': 60817,
#  'excellent': 39680,
#  'service': 81359,
#  'speed': 83559,
#  'response': 77872,
#  'query': 75521,
#  'second': 80968,
#  'certainly': 27470,
#  'buying': 25619,
#  'future': 43330,
#  'good': 45236,
#  'helvetica': 47220,
#  'njy5ldgznzqwndywniwxoda4mzm5mtesltixndi1mjmzmywxnduymduwnjy1': 65457,
#  'lc0xotm3otcyodq1lc04mdm5otm3odeslte2oduwntkxmzgsmtgxmtu2mjc5': 57749,
#  'miwxnduxmza5mjismtg2mzqwndg3lc04nzg2nzi0otesodyxndk3nja1ldix': 62380,
#  'ode3mtc0oswtmje0nzg5mzg1lduynjm3nja4nywxmzmynzqwnjg5lde5njk1': 67030,
#  'ntq0nzkslte3ndi0mdgzmtismty3mtg1otg2nywtmja5mzywmja3oswxmtuz': 66177,
#  'mtyynjixldk0mdcxndyxmswzoti0mtyymteslte1mjazodqxodksntc5nte3': 63556,
#  'oteylc0xntexmjy0otk2lc03mdywmta0njqsmte4mty4nza0myw1ntiymtcw': 68295,
#  'mduslti0oda4njaxncw5mzgwnjk5nzeslte3ndi0mdgzmtismty3mtg1otg2': 61335,
#  'nywxodc0mzi5otmsltixmtqwnjgxmcwxotk2mjc3mtg3lc0ymdy3ndm5mjqx': 66468,
#  'ldeznzk5mdaxmzgslte2mzc2mzy2odysltc1mdm2mzi4ncwymdkwotm1mju0': 57835,
#  'ldk5nzy1mdm0nywxmziznzi5otq4lc0ymda4mzuxnde2ldmxnzawmdczocw1': 57842,
#  'oti5mzyznjkslte2njq4mdyzodesmjqwotqzotazlc0yntuzodu5odkslte1': 68308,
#  'otuynjc4odcsltqxodyxnjaxmswtmtmzndkzmza0mswxmjy4mde5mzesmta1': 68360,
#  'mzuyotywmiwxmjazoty2ndcyldi4mjgxmtyymcwxnjg1mtq4nzuzlde2nti2': 64079,
#  'mtq2mtmsmtm1mzczmzc1mykncg0kchjvy2vzcyhhcikncn0ncnn0yxj0kckn': 63530,
#  'ci8vls0': 28176,
#  'dqo8l3njcmlwdd4ncg0kpc9ib2r5pg0kpc9odg1spg0k': 35492,
#  'wind': 95592,
#  'mates': 60944,
#  'visit': 92921,
#  'ukprankcalls': 90193,
#  'multi': 63629,
#  'mime': 62140,
#  'format': 42435,
#  '_nextpart_4488214905': 15149,
#  'plain': 71912,
#  'quoted': 75615,
#  'printable': 73192,
#  'looking': 59228,
#  'property': 73540,
#  'spain': 83387,
#  'don_t': 34993,
#  'waste': 94271,
#  'people': 70441,
#  'look': 59221,
#  'properties': 73539,
#  'advertised': 17342,
#  'sold': 83121,
#  'precious': 72885,
#  'inquiring': 52083,
#  'frustrating': 43043,
#  'market': 60791,
#  'moving': 63150,
#  'fast': 40734,
#  'frankly': 42714,
#  'estate': 39258,
#  'agents': 17768,
#  'update': 91080,
#  'company': 29579,
#  'sale': 80131,
#  'present': 73040,
#  'selection': 81116,
#  'current': 31422,
#  'specifically': 83523,
#  'fit': 41729,
#  'requirements': 77716,
#  'think': 87327,
#  'effort': 37718,
#  'save': 80370,
#  'finders': 41615,
#  'ways': 94341,
#  'local': 59075,
#  'papers': 69349,
#  'chasing': 27808,
#  'projects': 73458,
#  'longer': 59210,
#  'viewing': 92755,
#  'simply': 82183,
#  'form': 42425,
#  'press': 73066,
#  'button': 25602,
#  'hard': 46674,
#  'immediately': 51253,
#  'begin': 22916,
#  'right': 78422,
#  'villa': 92794,
#  'apartment': 19648,
#  'town': 88327,
#  'house': 48262,
#  'building': 25394,
#  'plot': 72070,
#  'land': 57465,
#  'bedrooms': 22872,
#  'location': 59098,
#  'sea': 80891,
#  'view': 92744,
#  'care': 26781,
#  'mountain': 63105,
#  'country': 30655,
#  'near': 64701,
#  'city': 28382,
#  'pool': 72437,
#  'range': 76284,
#  'planning': 71937,
#  'come': 29436,
#  'months': 62916,
#  'mail': 60312,
#  'telephone': 86754,
#  'dhtml': 33867,
#  'editing': 37554,
#  'div': 34529,
#  'id': 49828,
#  '3dautonumber1': 6841,
#  '111111': 1817,
#  '3d0': 6386,
#  '3d92': 6737,
#  'siteserver': 82308,
#  'flyer': 42069,
#  'logo2': 59165,
#  '3d757': 6714,
#  '3dautonumber2': 6842,
#  '3d83': 6728,
#  '101': 1549,
#  '0066cc': 253,
#  '3d21': 6536,
#  '74': 11261,
#  '23': 4214,
#  '3d36': 6598,
#  'margin': 60758,
#  '0px': 1249,
#  'class': 28606,
#  '3dmsonormal': 7105,
#  '3dcenter': 6892,
#  'span': 83450,
#  '28pt': 4776,
#  'blue': 24106,
#  '17pt': 2684,
#  'red': 76938,
#  'strong': 84630,
#  'black': 23893,
#  '3darial': 6833,
#  '3dmsobodytext2': 7103,
#  '0000ff': 53,
#  '3dmsobodytext3': 7104,
#  'lang': 57484,
#  '3den': 6950,
#  'gb': 44019,
#  '3djavascript': 7052,
#  '3dfrontpage_form1': 6982,
#  'onsubmit': 67699,
#  'return': 78025,
#  'frontpage_form1_validator': 43006,
#  'action': 16898,
#  '3dhttp': 7019,
#  'wwc': 96503,
#  'mailform': 60377,
#  'pl': 71889,
#  'method': 61737,
#  '3dpost': 7166,
#  '3dautonumber4': 6844,
#  '3d1': 6417,
#  '22pt': 4180,
#  '3dautonumber5': 6845,
#  'input': 52071,
#  '3dhidden': 7010,
#  '3dprint_blank_fields': 7169,
#  '3dremote_host': 7193,
#  'remote_addr': 77454,
#  '3denv_report': 6952,
#  '3dcostasol1': 6909,
#  'freeuk': 42853,
#  '3drecipient': 7185,
#  'thank_you': 87163,
#  'htm': 48469,
#  '3dredirect': 7190,
#  '39': 6183,
#  '13pt': 2214,
#  'select': 81106,
#  '3dtype_of_property': 7270,
#  'selected': 81113,
#  'multiple': 63658,
#  '3dhow_many_bedrooms': 7017,
#  '3dlocation': 7068,
#  '3dsea_view': 7218,
#  '3dmountain_view': 7099,
#  '3dcheckbox': 6893,
#  '3don': 7139,
#  '3dc1': 6880,
#  '3dc2': 6881,
#  '3dpool': 7164,
#  'webbot': 94981,
#  'bot': 24623,
#  'validation': 92040,
#  'separators': 81247,
#  '3dprice_range': 7168,
#  '3dplaning_to_come_over': 7159,
#  '3dname': 7110,
#  '3demail': 6948,
#  '3dtelephone': 7239,
#  'integer': 52270,
#  '3d4': 6607,
#  '3dcountry_code': 6910,
#  '3dsubmit': 7230,
#  'proceed': 73288,
#  '3db1': 6850,
#  '3dreset': 7207,
#  '3db2': 6851,
#  'h1': 46221,
#  '3d52': 6648,
#  'logo': 59163,
#  'copy': 30455,
#  '3d425': 6618,
#  'h2': 46237,
#  '15pt': 2454,
#  '3dautonumber6': 6846,
#  '3d8': 6723,
#  '3d509': 6646,
#  'vertical_pic': 92475,
#  '3d170': 6506,
#  '3dautonumber7': 6847,
#  '3d97': 6749,
#  '3d19': 6519,
#  'important': 51356,
#  'domain': 34956,
#  'names': 64368,
#  'finally': 41591,
#  'available': 21047,
#  'general': 44238,
#  'public': 74013,
#  'discount': 34270,
#  'prices': 73143,
#  'register': 77175,
#  'exciting': 39714,
#  'biz': 23754,
#  '95': 13787,
#  'brand': 24872,
#  'extensions': 40037,
#  'recently': 76800,
#  'icann': 49700,
#  'rights': 78433,
#  'biggest': 23562,
#  'benefit': 23038,
#  'currently': 31433,
#  'easier': 37272,
#  'attractive': 20763,
#  'easy': 37289,
#  'remember': 77426,
#  'affordable': 17601,
#  'domains': 34965,
#  'registration': 77185,
#  'fees': 41110,
#  'include': 51527,
#  'access': 16655,
#  'use': 91315,
#  'panel': 69308,
#  'manage': 60592,
#  'sincerely': 82208,
#  'administrator': 17205,
#  'promotional': 73492,
#  'centralremovalservice': 27420,
#  'bin': 23627,
#  'g1': 43562,
#  'ss2': 83915,
#  '5592oxer3': 9274,
#  '424uqkh2259kcdl5': 8017,
#  '189geil31': 2775,
#  '000000000000000000000': 9,
#  '7bit': 11595,
#  'section1': 80999,
#  'msobodytext': 63441,
#  'justify': 55060,
#  'consantly': 30056,
#  'bombarded': 24458,
#  'called': 26528,
#  'making': 60533,
#  'systems': 85740,
#  'teases': 86614,
#  'said': 80100,
#  'blind': 23997,
#  'sides': 82021,
#  'demanding': 33127,
#  'upfront': 91092,
#  'slick': 82608,
#  'way': 94335,
#  'fact': 40520,
#  'skeptical': 82427,
#  'internet': 52404,
#  'hype': 48803,
#  'probably': 73267,
#  'fortunate': 42498,
#  'main': 60452,
#  'slowed': 82669,
#  'self': 81125,
#  'employed': 38374,
#  'life': 58442,
#  'looked': 59223,
#  'lifestyle': 58461,
#  'assist': 20503,
#  'paying': 69694,
#  'bills': 23620,
#  'working': 96050,
#  'death': 32725,
#  'loosing': 59262,
#  'proposal': 73556,
#  'try': 88914,
#  'investment': 52605,
#  'interested': 52352,
#  'provided': 73661,
#  'regret': 77194,
#  'did': 33957,
#  'recommend': 76857,
#  'true': 88876,
#  'word': 96017,
#  'mean': 61362,
#  'absolutely': 16493,
#  'track': 88465,
#  'results': 77941,
#  'efforts': 37721,
#  'instantly': 52201,
#  'updated': 91082,
#  'daily': 32175,
#  'especially': 39215,
#  'liked': 58503,
#  'idea': 49977,
#  'personal': 70607,
#  'real': 76643,
#  'informed': 51883,
#  'statistics': 84200,
#  'quite': 75585,
#  'logical': 59154,
#  'opened': 67785,
#  'fair': 40578,
#  've': 92282,
#  'specific': 83522,
#  'facts': 40535,
#  'seriously': 81307,
#  'consider': 30086,
#  'teasing': 86615,
#  'grand': 45483,
#  'testimonies': 86960,
#  'kidding': 56080,
#  'unlike': 90799,
#  'programs': 73427,
#  'overall': 68543,
#  'plan': 71920,
#  'forking': 42418,
#  'worst': 96109,
#  'joining': 54669,
#  'finding': 41617,
#  'late': 57585,
#  'wasting': 94277,
#  'trying': 88916,
#  'figure': 41512,
#  'straightforward': 84505,
#  'informative': 51882,
#  'providing': 73666,
#  'things': 87324,
#  'know': 56461,
#  'does': 34891,
#  'ultimate': 90279,
#  'deal': 32703,
#  'makers': 60528,
#  'breakers': 24928,
#  'disclosed': 34256,
#  'discovering': 34287,
#  'maybe': 61044,
#  'hooked': 48116,
#  'locked': 59107,
#  'battle': 22562,
#  'platinum': 71964,
#  'stands': 84093,
#  'misleading': 62304,
#  'hook': 48112,
#  'promise': 73478,
#  'lofty': 59134,
#  'mega': 61469,
#  'jackpots': 53771,
#  'pockets': 72269,
#  'headlines': 47046,
#  'yeah': 98498,
#  'thing': 87320,
#  'launched': 57628,
#  'weeks': 95096,
#  'ago': 17848,
#  'earnings': 37256,
#  'far': 40689,
#  'tell': 86773,
#  'wouldn': 96124,
#  'able': 16402,
#  'corporate': 30516,
#  'unusually': 91003,
#  'thorough': 87405,
#  'timely': 87635,
#  'motivating': 63074,
#  'minutes': 62236,
#  'decent': 32793,
#  'explosive': 39970,
#  'potential': 72648,
#  'fully': 43250,
#  'loaded': 59043,
#  'hi': 47484,
#  'tech': 86624,
#  'member': 61536,
#  'support': 85179,
#  'protective': 73617,
#  'safeguards': 80072,
#  ...}

# %%
X_train, X_test, y_train, y_test = train_test_split(all_features, data.CATEGORY, test_size=0.3, random_state=88)

# %%
X_train.shape
# Out:
# (4057, 102694)

# %%
X_test.shape
# Out:
# (1739, 102694)

# %%
classifier = MultinomialNB()

# %%
classifier.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
nr_correct = (y_test == classifier.predict(X_test)).sum()

# %%
print(f'{nr_correct} documents classified correctly.')
# Out:
# 1654 documents classified correctly.

# %%
nr_incorrect = y_test.size - nr_correct

# %%
print(f"Number of documents incorrectly classified is {nr_incorrect}")
# Out:
# Number of documents incorrectly classified is 85

# %%
fraction_wrong = nr_incorrect / (nr_incorrect + nr_correct)
print (f"The testing accuracy of the model is {1-fraction_wrong:.2%}")
# Out:
# The testing accuracy of the model is 95.11%

# %%
classifier.score(X_test, y_test)
# Out:
# 0.9511213341000575

# %%
recall_score(y_test, classifier.predict(X_test))
# Out:
# 0.855595667870036

# %%
precision_score(y_test, classifier.predict(X_test))
# Out:
# 0.9895615866388309

# %%
f1_score(y_test, classifier.predict(X_test))
# Out:
# 0.9177153920619555

# %%
example = ['get viagra for free now',
          'need a mortgage? We can arrange a call for a quote',
          'Can you help me with the project for tomorrow? Thanks.',
          'Hi Jonathan, what about playing tennis this afternoon?',
          'Systems engineering is an interdisciplinary field of engineering and engineering management that focuses on how to design, integrate, and manage complex systems over their life cycles. At its core, systems engineering utilizes systems thinking principles to organize this body of knowledge. The individual outcome of such efforts, an engineered system, can be defined as a combination of components that work in synergy to collectively perform a useful function.']

# %%
doc_term_matrix = vectorizer.transform(example)

# %%
classifier.predict(doc_term_matrix)
# Out:
# array([1, 1, 0, 0, 0], dtype=int64)
